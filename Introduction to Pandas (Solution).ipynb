# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# @author Annice Najafi <br>
# Date: 091521

# %% [markdown]
# In the following example we take a look at the Pandas module and learn how to read a csv file and store it as a dataframe, filter it based on values in a column and plot it using Matplotlib

# %% [markdown]
# <h3>Import Files in Pandas</h3>

# %%
#import the pandas module as pd
import pandas as pd
#Read as csv file
df = pd.read_csv("AAPL.csv")
#other types of delimeters add a delimeter argument

# %%
#take a look at the dataframe
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100600  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095352  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088353  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090540   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.093165   73449600

# %%
#print columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# <h3>Extracting and Filtering Columns</h3>

# %%
#extract a specific column
df['Open']
# Out:
# 0          0.128348
# 1          0.122210
# 2          0.113281
# 3          0.115513
# 4          0.118862
#             ...
# 10267    152.830002
# 10268    153.869995
# 10269    153.759995
# 10270    154.970001
# 10271    156.979996
# Name: Open, Length: 10272, dtype: float64

# %%
#convert column to a different type
#extract as list
df['Date'] = pd.to_datetime(df['Date'])

# %%
#Extract column as dataframe
df[['Open']]
type(df[['Date']])
# Out:
# pandas.core.frame.DataFrame

# %%
#extract two or more columns
df[['Open', 'Close']]
# Out:
#              Open       Close
# 0        0.128348    0.128348
# 1        0.122210    0.121652
# 2        0.113281    0.112723
# 3        0.115513    0.115513
# 4        0.118862    0.118862
# ...           ...         ...
# 10267  152.830002  152.509995
# 10268  153.869995  153.649994
# 10269  153.759995  154.300003
# 10270  154.970001  156.690002
# 10271  156.979996  155.110001
#
# [10272 rows x 2 columns]

# %%
#Filter dataframe based on value in one column
df[df['Open'] >0.2]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 548   1983-02-11    0.202567    0.210938    0.202567    0.207589    0.162710
# 549   1983-02-14    0.207589    0.207589    0.201451    0.206473    0.161835
# 550   1983-02-15    0.206473    0.208147    0.200335    0.202567    0.158773
# 551   1983-02-16    0.202567    0.202567    0.197545    0.198661    0.155712
# 554   1983-02-22    0.203683    0.213170    0.203683    0.207589    0.162710
# ...          ...         ...         ...         ...         ...         ...
# 10267 2021-09-01  152.830002  154.979996  152.339996  152.509995  152.509995
# 10268 2021-09-02  153.869995  154.720001  152.399994  153.649994  153.649994
# 10269 2021-09-03  153.759995  154.630005  153.089996  154.300003  154.300003
# 10270 2021-09-07  154.970001  157.259995  154.389999  156.690002  156.690002
# 10271 2021-09-08  156.979996  157.039993  153.979996  155.110001  155.110001
#
#           Volume
# 548    203548800
# ...

# %%
#Check multiple Conditions
df[(df['Open'] > 0.2) | (df['Close'] >0.5)]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 548   1983-02-11    0.202567    0.210938    0.202567    0.207589    0.162710
# 549   1983-02-14    0.207589    0.207589    0.201451    0.206473    0.161835
# 550   1983-02-15    0.206473    0.208147    0.200335    0.202567    0.158773
# 551   1983-02-16    0.202567    0.202567    0.197545    0.198661    0.155712
# 554   1983-02-22    0.203683    0.213170    0.203683    0.207589    0.162710
# ...          ...         ...         ...         ...         ...         ...
# 10267 2021-09-01  152.830002  154.979996  152.339996  152.509995  152.509995
# 10268 2021-09-02  153.869995  154.720001  152.399994  153.649994  153.649994
# 10269 2021-09-03  153.759995  154.630005  153.089996  154.300003  154.300003
# 10270 2021-09-07  154.970001  157.259995  154.389999  156.690002  156.690002
# 10271 2021-09-08  156.979996  157.039993  153.979996  155.110001  155.110001
#
#           Volume
# 548    203548800
# ...

# %%
#Take the row where the maximum value of something happens
df[df['High']==df['High'].max()]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 10270 2021-09-07  154.970001  157.259995  154.389999  156.690002  156.690002
#
#          Volume
# 10270  82278300

# %%
#slice a dataframe
df[2:3]
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088353  105728000

# %%
#Extract a specific row of a dataframe
df.iloc[3]
# Out:
# Date         1980-12-17 00:00:00
# Open                    0.115513
# High                    0.116071
# Low                     0.115513
# Close                   0.115513
# Adj Close                0.09054
# Volume                  86441600
# Name: 3, dtype: object

# %%
#Create a new column
df["Difference between the Starting and Closing Price"] = df['Close'] - df['Open']

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100600  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095352  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088353  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090540   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.093165   73449600
#
#    Difference between the Starting and Closing Price
# 0                                           0.000000
# 1                                          -0.000558
# 2                                          -0.000558
# 3                                           0.000000
# 4                                           0.000000

# %%
#Drop a column
df = df.drop(columns="Difference between the Starting and Closing Price")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100600
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095352
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088353
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090540
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093165
# ...          ...         ...         ...         ...         ...         ...
# 10267 2021-09-01  152.830002  154.979996  152.339996  152.509995  152.509995
# 10268 2021-09-02  153.869995  154.720001  152.399994  153.649994  153.649994
# 10269 2021-09-03  153.759995  154.630005  153.089996  154.300003  154.300003
# 10270 2021-09-07  154.970001  157.259995  154.389999  156.690002  156.690002
# 10271 2021-09-08  156.979996  157.039993  153.979996  155.110001  155.110001
#
#           Volume
# 0      469033600
# ...

# %% [markdown]
# <h3>Iterate Through Rows</h3>

# %%
#iterate through rows of dataframe
for idx, val in df.iterrows():
    print (idx, val)
    if idx == 50:
        break
# Out:
# 0 Date         1980-12-12 00:00:00
# Open                    0.128348
# High                    0.128906
# Low                     0.128348
# Close                   0.128348
# Adj Close                 0.1006
# Volume                 469033600
# Name: 0, dtype: object
# 1 Date         1980-12-15 00:00:00
# Open                     0.12221
# High                     0.12221
# Low                     0.121652
# Close                   0.121652
# Adj Close               0.095352
# Volume                 175884800
# Name: 1, dtype: object
# 2 Date         1980-12-16 00:00:00
# Open                    0.113281
# High                    0.113281
# Low                     0.112723
# Close                   0.112723
# Adj Close               0.088353
# Volume                 105728000
# Name: 2, dtype: object
# 3 Date         1980-12-17 00:00:00
# Open                    0.115513
# High                    0.116071
# Low                     0.115513
# Close                   0.115513
# ...

# %% [markdown]
# # Plot a Column

# %%
import matplotlib.pyplot as plt
import numpy as np

x_vals = np.arange(0, len(df['Date']), 1)
y_vals = df['High']

plt.plot(x_vals, y_vals, 'b')
plt.xlabel('Day')
plt.ylabel('high')
plt.title('Apple Highest Stock Price')
# Out:
# Text(0.5, 1.0, 'Apple Highest Stock Price')

# %% [markdown]
# <h3>Save as a csv file</h3>

# %%
#save as csv file
df.to_csv('pandas.csv')

# %% [markdown]
# <h3>Create a dataframe</h3>

# %%
#create a new dataframe
data_dict = {
    "People": ["Dalia Margolis", "Ljudmila Vetrova", "Eric Soders", "Jordan Cross", "Sierra Knox", "Jason Portman", "Silvio Caruso", "Ana Isabel Reyes", "Robert Knox", "Reveille", "Jesse Pinkman"],
    "Location": ["Paris", "Haven Island", "Hokkaido", "Bangkok", "Miami", "Haven Island", "Sapienza", "Bogota", "Miami", "College Station", "Albuquerque"]
}
data = pd.DataFrame(data_dict)

# %%
data
# Out:
#               People         Location
# 0     Dalia Margolis            Paris
# 1   Ljudmila Vetrova     Haven Island
# 2        Eric Soders         Hokkaido
# 3       Jordan Cross          Bangkok
# 4        Sierra Knox            Miami
# 5      Jason Portman     Haven Island
# 6      Silvio Caruso         Sapienza
# 7   Ana Isabel Reyes           Bogota
# 8        Robert Knox            Miami
# 9           Reveille  College Station
# 10     Jesse Pinkman      Albuquerque

# %%
#find columns with certain words 
import re 
data = data.loc[data['People'].str.contains("Knox")]

# %%
data.sort_values(by=['Location'], ascending=False)
# Out:
#               People         Location
# 6      Silvio Caruso         Sapienza
# 0     Dalia Margolis            Paris
# 4        Sierra Knox            Miami
# 8        Robert Knox            Miami
# 2        Eric Soders         Hokkaido
# 1   Ljudmila Vetrova     Haven Island
# 5      Jason Portman     Haven Island
# 9           Reveille  College Station
# 7   Ana Isabel Reyes           Bogota
# 3       Jordan Cross          Bangkok
# 10     Jesse Pinkman      Albuquerque

# %% [markdown]
# # Reset Index

# %%
data
# Out:
#         People Location
# 4  Sierra Knox    Miami
# 8  Robert Knox    Miami

# %%
#reset the index
data.reset_index(inplace=True)

# %%
data.drop(columns="index")
# Out:
#         People Location
# 0  Sierra Knox    Miami
# 1  Robert Knox    Miami

# %% [markdown]
# # Exercise

# %% [markdown]
# Description: In this example we take a look at Apple's stock prices and write a
# program to plot an OHLC chart. To learn more about OHLC plots visit
# https://www.investopedia.com/terms/o/ohlcchart.asp
#
# #Dataset Source:
#     downloaded from Kaggle ==> https://www.kaggle.com/meetnagadia/apple-stock-price-from-19802021?select=AAPL.csv

# %% [markdown]
# TO DO List:<ul>
#     <li> Plot the data only from July 2020 to the end (month = 7)</li>
#     <li> Change the colors from green to yellow and red to blue</li>
#     </ul>

# %%
#Read csv file using pandas
df = pd.read_csv("/Users/annicenajafi/Desktop/apple_stock_analysis/AAPL.csv")
df['Date'] = pd.to_datetime(df['Date'])

# %%
'''
Let's only look at recent data more specifically from 2020 to the most recent data
But first we have to convert our date column to datetime type so we would be able to 
treat it as date
'''
df = df[(df['Date'].dt.year > 2020) & (df['Date'].dt.month > 7)] 
df.reset_index(inplace=True)

# %%
#Let's define the x axis
x_vals = np.arange(0,len(df['Date']))

# %%
'''
Let's iterate through the rows and plot a candle stick for every date
What we do is we plot a vertical line that starts from the low point and ends
at the high point for every date
'''
for idx, val in df.iterrows():
    #Change the color to red if opening price is more than closing price 
    #Otherwise change it to green
    if val['Open'] > val['Close']: 
        col = 'blue'
    else:
        col ='yellow'
    
    plt.plot([x_vals[idx], x_vals[idx]], [val['Low'], val['High']], color=col)
    #add a horizontal line to the left to show the openning price
    plt.plot([x_vals[idx], x_vals[idx]-0.05], 
             [val['Open'], val['Open']], 
             color=col)
    #add a horizontal line to the right to show the closing price
    plt.plot([x_vals[idx], x_vals[idx]+0.05], 
             [val['Close'], val['Close']], 
             color=col)
    
#Change the x axis tick marks
plt.xticks(x_vals[::50], df.Date.dt.date[::50])  
#change the x axis label
plt.xlabel('Date')
#change the y label 
plt.ylabel('USD')
#Change the title of the plot
plt.title('Apple Stock Price', loc='left', fontsize=20)
#let's show the plot

plt.show()

# %% [markdown]
# Texas A&M University <br>
# BMEN 207 <br>
# Fall 2021 <br>
